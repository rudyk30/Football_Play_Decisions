# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np 
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from imblearn.metrics import classification_report_imbalanced
from imblearn.ensemble import BalancedRandomForestClassifier
from imblearn.ensemble import EasyEnsembleClassifier
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import ClusterCentroids
from imblearn.combine import SMOTEENN

# %%
# loading the data in 

file_path = Path("Resources/clean_nfl_data.csv")

df = pd.read_csv(file_path)

df
# Out:
#       Unnamed: 0  play_id home_team away_team season_type  week posteam  \
# 0              2       55       TEN       ARI         REG     1     TEN
# 1              3       76       TEN       ARI         REG     1     TEN
# 2              4      100       TEN       ARI         REG     1     TEN
# 3              6      152       TEN       ARI         REG     1     ARI
# 4              7      181       TEN       ARI         REG     1     ARI
# ...          ...      ...       ...       ...         ...   ...     ...
# 5018        7202     1908        KC       LAC         REG     3      KC
# 5019        7209     2045        KC       LAC         REG     3      KC
# 5020        7210     2069        KC       LAC         REG     3      KC
# 5021        7211     2090        KC       LAC         REG     3      KC
# 5022        7212     2112        KC       LAC         REG     3      KC
#
#      posteam_type defteam side_of_field  ...  jersey_number          id  \
# 0            home     ARI           TEN  ...           22.0  00-0032764
# 1            home     ARI           TEN  ...           17.0  00-0029701
# 2            home     ARI           TEN  ...           17.0  00-0029701
# 3            away     TEN           ARI  ...            1.0  00-0035228
# 4            away     TEN           TEN  ...            1.0  00-0035228
# ...           ...     ...           ...  ...            ...         ...
# 5018         home     LAC           LAC  ...           15.0  00-0033873
# 5019         home     LAC            KC  ...           15.0  00-0033873
# 5020         home     LAC            KC  ...           25.0  00-0036360
# 5021         home     LAC            KC  ...           15.0  00-0033873
# 5022         home     LAC            KC  ...            NaN         NaN
#
#         qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0    -1.399805       NaN                NaN                  NaN          NaN
# 1     0.032412  1.165133           5.803177                  4.0     0.896654
# 2    -1.532898  0.256036           4.147637                  2.0     0.965009
# 3     2.692890  0.567838           7.420427                  4.0     1.000000
# 4    -1.009908       NaN                NaN                  NaN          NaN
# ...        ...       ...                ...                  ...          ...
# 5018 -0.127200  0.719127           9.721938                  9.0     0.123323
# 5019  0.808641  0.211871           3.551042                  1.0     1.000000
# 5020  0.619626       NaN                NaN                  NaN          NaN
# 5021 -0.537923  0.600601           7.770729                  4.0     1.000000
# 5022       NaN       NaN                NaN                  NaN          NaN
#
#        xyac_fd     xpass    pass_oe
# 0          NaN  0.491433 -49.143300
# 1     0.125098  0.697346  30.265415
# 2     0.965009  0.978253   2.174652
# 3     1.000000  0.458989  54.101130
# 4          NaN  0.419833 -41.983326
# ...        ...       ...        ...
# 5018  0.108665  0.974273   2.572680
# 5019  0.999365  0.482662  51.733780
# 5020       NaN  0.448400 -44.839950
# 5021  1.000000  0.453813  54.618725
# 5022       NaN       NaN        NaN
#
# [5023 rows x 186 columns]

# %%
df = df.dropna(axis = 'columns' , how='any')

df = df.dropna()

# %%
df['play_type'] = df['play_type'].astype(str).str.replace('run' , '1')
df['play_type'] = df['play_type'].astype(str).str.replace('pass' , '0')
df['play_type'] = df['play_type'].astype('float')
df
# Out:
#       Unnamed: 0  play_id home_team away_team season_type  week posteam  \
# 0              2       55       TEN       ARI         REG     1     TEN
# 1              3       76       TEN       ARI         REG     1     TEN
# 2              4      100       TEN       ARI         REG     1     TEN
# 3              6      152       TEN       ARI         REG     1     ARI
# 4              7      181       TEN       ARI         REG     1     ARI
# ...          ...      ...       ...       ...         ...   ...     ...
# 5018        7202     1908        KC       LAC         REG     3      KC
# 5019        7209     2045        KC       LAC         REG     3      KC
# 5020        7210     2069        KC       LAC         REG     3      KC
# 5021        7211     2090        KC       LAC         REG     3      KC
# 5022        7212     2112        KC       LAC         REG     3      KC
#
#      posteam_type defteam side_of_field  ...  touchdown pass_touchdown  \
# 0            home     ARI           TEN  ...          0              0
# 1            home     ARI           TEN  ...          0              0
# 2            home     ARI           TEN  ...          0              0
# 3            away     TEN           ARI  ...          0              0
# 4            away     TEN           TEN  ...          0              0
# ...           ...     ...           ...  ...        ...            ...
# 5018         home     LAC           LAC  ...          0              0
# 5019         home     LAC            KC  ...          0              0
# 5020         home     LAC            KC  ...          0              0
# 5021         home     LAC            KC  ...          0              0
# 5022         home     LAC            KC  ...          0              0
#
#      rush_touchdown  complete_pass  season series series_success  \
# 0                 0              0    2021      1              0
# 1                 0              1    2021      1              0
# 2                 0              0    2021      1              0
# 3                 0              1    2021      2              1
# 4                 0              0    2021      3              1
# ...             ...            ...     ...    ...            ...
# 5018              0              1    2021     30              0
# 5019              0              1    2021     32              1
# 5020              0              0    2021     33              1
# 5021              0              0    2021     34              1
# 5022              0              0    2021     34              1
#
#       series_result  start_time  time_of_day
# 0              Punt    13:00:00     17:06:37
# 1              Punt    13:00:00     17:07:14
# 2              Punt    13:00:00     17:07:54
# 3        First down    13:00:00     17:09:19
# 4        First down    13:00:00     17:09:59
# ...             ...         ...          ...
# 5018     Field goal    13:00:00     18:20:43
# 5019     First down    13:00:00     18:39:10
# 5020     First down    13:00:00     18:39:40
# 5021     First down    13:00:00     18:40:18
# 5022     First down    13:00:00      18:40:5
#
# [5023 rows x 101 columns]

# %%
x = {'run': '1.0' , 'pass': '0.0'}
df = df.replace(x)

df.reset_index(inplace=True, drop=True)

df.head()
# Out:
#    Unnamed: 0  play_id home_team away_team season_type  week posteam  \
# 0           2       55       TEN       ARI         REG     1     TEN
# 1           3       76       TEN       ARI         REG     1     TEN
# 2           4      100       TEN       ARI         REG     1     TEN
# 3           6      152       TEN       ARI         REG     1     ARI
# 4           7      181       TEN       ARI         REG     1     ARI
#
#   posteam_type defteam side_of_field  ...  touchdown pass_touchdown  \
# 0         home     ARI           TEN  ...          0              0
# 1         home     ARI           TEN  ...          0              0
# 2         home     ARI           TEN  ...          0              0
# 3         away     TEN           ARI  ...          0              0
# 4         away     TEN           TEN  ...          0              0
#
#   rush_touchdown  complete_pass  season series series_success  series_result  \
# 0              0              0    2021      1              0           Punt
# 1              0              1    2021      1              0           Punt
# 2              0              0    2021      1              0           Punt
# 3              0              1    2021      2              1     First down
# 4              0              0    2021      3              1     First down
#
#    start_time  time_of_day
# 0    13:00:00     17:06:37
# 1    13:00:00     17:07:14
# 2    13:00:00     17:07:54
# 3    13:00:00     17:09:19
# 4    13:00:00     17:09:59
#
# [5 rows x 101 columns]

# %%
X = df.drop('play_type' , axis=1)

X = pd.get_dummies(X)

# Create our target
y = df['play_type']

# %%
X.describe()
# Out:
#         Unnamed: 0      play_id         week  yardline_100        drive  \
# count  5023.000000  5023.000000  5023.000000   5023.000000  5023.000000
# mean   3580.608600  2061.084412     1.795541     50.914593    11.062512
# std    2084.122874  1221.906625     0.756101     24.285391     6.481453
# min       2.000000    54.000000     1.000000      1.000000     1.000000
# 25%    1762.500000   995.500000     1.000000     33.000000     6.000000
# 50%    3567.000000  2050.000000     2.000000     54.000000    11.000000
# 75%    5391.500000  3093.500000     2.000000     72.000000    16.000000
# max    7212.000000  4878.000000     3.000000     99.000000    27.000000
#
#                qtr      ydstogo       ydsnet  yards_gained      shotgun  ...  \
# count  5023.000000  5023.000000  5023.000000   5023.000000  5023.000000  ...
# mean      2.554051     8.486363    45.364324      5.661358     0.657376  ...
# std       1.132858     4.057110    28.252437      8.676368     0.474634  ...
# min       1.000000     0.000000   -16.000000    -18.000000     0.000000  ...
# 25%       2.000000     6.000000    21.000000      0.000000     0.000000  ...
# 50%       3.000000    10.000000    48.000000      4.000000     1.000000  ...
# 75%       4.000000    10.000000    72.000000      8.000000     1.000000  ...
# max       5.000000    39.000000    97.000000     91.000000     1.000000  ...
#
#        time_of_day_3:49:24  time_of_day_3:49:32  time_of_day_3:50:02  \
# count          5023.000000          5023.000000          5023.000000
# mean              0.000199             0.000199             0.000199
# std               0.014110             0.014110             0.014110
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               1.000000             1.000000             1.000000
#
#        time_of_day_3:50:17  time_of_day_3:50:44  time_of_day_3:50:59  \
# count          5023.000000          5023.000000          5023.000000
# mean              0.000199             0.000199             0.000199
# std               0.014110             0.014110             0.014110
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               1.000000             1.000000             1.000000
#
#        time_of_day_3:51:30  time_of_day_3:52:40  time_of_day_3:54:18  \
# count          5023.000000          5023.000000          5023.000000
# mean              0.000199             0.000199             0.000199
# std               0.014110             0.014110             0.014110
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               0.000000             0.000000             0.000000
# 75%               0.000000             0.000000             0.000000
# max               1.000000             1.000000             1.000000
#
#        time_of_day_3:54:46
# count          5023.000000
# mean              0.000199
# std               0.014110
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               0.000000
# max               1.000000
#
# [8 rows x 7135 columns]

# %%
y.value_counts()
# Out:
# 0.0    2995
# 1.0    2028
# Name: play_type, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

X_train.shape
# Out:
# (3767, 7135)

# %%
brfc = BalancedRandomForestClassifier(n_estimators=100, random_state=1)
brfc.fit(X_train, y_train)
# Out:
# BalancedRandomForestClassifier(random_state=1)

# %%
y_pred = brfc.predict(X_test)

balanced_accuracy_score(y_test , y_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test, y_pred)
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#         0.0       1.00      1.00      1.00      1.00      1.00      1.00       749
#         1.0       1.00      1.00      1.00      1.00      1.00      1.00       507
#
# avg / total       1.00      1.00      1.00      1.00      1.00      1.00      1256

# %%
matrix_st = confusion_matrix(y_test, y_pred)

cm4_df = pd.DataFrame(matrix_st, index=["Actual Run", "Actual Pass"], columns=["Predicted Run", "Predicted Pass"])
cm4_df
# Out:
#              Predicted Run  Predicted Pass
# Actual Run             749               0
# Actual Pass              0             507

# %%
confusion_matrix(y_test , y_pred)
# Out:
# array([[749,   0],
#        [  0, 507]])

# %% [markdown]
# #### Combination (Over and Under) Sampling

# %%
smote_enn = SMOTEENN(random_state=1)
X_resample4, y_resample4 = smote_enn.fit_resample(X, y)
Counter(y_resample4)
# Out:
# Counter({0.0: 724, 1.0: 827})

# %%
model = LogisticRegression(solver='lbfgs', random_state=1)

model.fit(X_resample4, y_resample4)
# Out:
# LogisticRegression(random_state=1)

# %%
y_pred_st = model.predict(X_test)

acc_score4 = balanced_accuracy_score(y_test, y_pred_st)
acc_score4
# Out:
# 0.6326884234864105

# %%
matrix_st = confusion_matrix(y_test, y_pred_st)

cm4_df = pd.DataFrame(matrix_st, index=["Actual Run", "Actual Pass"], columns=["Predicted Run", "Predicted Pass"])
cm4_df
# Out:
#              Predicted Run  Predicted Pass
# Actual Run             379             370
# Actual Pass            122             385

# %%
print(classification_report_imbalanced(y_test, y_pred_st))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#         0.0       0.76      0.51      0.76      0.61      0.62      0.37       749
#         1.0       0.51      0.76      0.51      0.61      0.62      0.39       507
#
# avg / total       0.66      0.61      0.66      0.61      0.62      0.38      1256
